# %%
import boto3
import pandas as pd

# %%
s3 = boto3.client("s3")

s3 = boto3.client(
    's3',
    aws_access_key_id='YOUR_ACCESS_KEY',
    aws_secret_access_key='YOUR_SECRET_KEY',
    region_name='YOUR_REGION'
)

# %%
#cleaning process
df_lp = pd.read_csv(r'/Users/rema/Downloads/LP(in).csv')

# %%
df_lp = df_lp.apply(lambda x: x.str.replace('\t', '', regex=False) if x.dtype == "object" else x)

# %%
df_lp = df_lp.set_index('EntityID')

# %%
keep_columns = ['Name', 'Status', 'IncorpDate', 'IncorpState', 'Street1', 'Street2', 'City', 'State', 'Zip']

df_lp = df_lp[keep_columns]

# %%
df_lp.head(50)
# Out:
#                                                          Name      Status  \
# EntityID
# L0002297                                         RM LAND L.P.  INACTIVE
# L0005506                              O J LIMITED PARTNERSHIP  INACTIVE
# L0005704                             JORDAN FAMILY FARM, L.P.  INACTIVE
# L0005886                            M. S. F. INVESTORS, L. P.  INACTIVE
# L0004970                           SOUTHSIDE ASSOCIATES, L.P.  INACTIVE
# L0006215                        HIGHLANDS LIMITED PARTNERSHIP  INACTIVE
# M0006397                 CHESAPEAKE HOTEL LIMITED PARTNERSHIP  INACTIVE
# L0005035    GENERAL INVESTORS REALTY ASSOCIATES, A LIMITED...  ACTIVE
# L0001869         HUNTINGTON AVENUE REALTY LIMITED PARTNERSHIP  INACTIVE
# L0006793                          RAPHINE LIMITED PARTNERSHIP  INACTIVE
# M0007015    LERNER DEVELOPMENT COMPANY LIMITED PARTNERSHIP...  ACTIVE
# M0007114               BRANDERMILL-OXFORD LIMITED PARTNERSHIP  INACTIVE
# L0007932                          CROSSWINDS ASSOCIATES, L.P.  INACTIVE
# L0007213                                           NVR L.P.    INACTIVE
# L0007171                                        NVREALTY L.P.  INACTIVE
# M0005746                        JIM KOONS LIMITED PARTNERSHIP  INACTIVE
# L0007551                                   QUALITY LINK, L.P.  INACTIVE
# M0004996                   MEADOWS-I LIMITED PARTNERSHIP, THE  INACTIVE
# M0001463    WESTFIELDS CORPORATE CENTER ASSOCIATES LIMITED...  INACTIVE
# L0001307                      LEE MADISON LIMITED PARTNERSHIP  ACTIVE
# L0006470       THETA DELTA CHI RENOVATION LIMITED PARTNERSHIP  ACTIVE
# M0005910                                    CBM One Hotels LP  INACTIVE
# L0004434        FOURTH GATEWAY ASSOCIATES LIMITED PARTNERSHIP  INACTIVE
# M0006868      EAST CHRISTIANSBURG HOUSING LIMITED PARTNERSHIP  ACTIVE
# L0008559                                  TGM INVESTORS, L.P.  INACTIVE
# L0008450                 DUBLIN FAIRACRES LIMITED PARTNERSHIP  ACTIVE
# L0008500                         PARK CENTER ASSOCIATES, L.P.  INACTIVE
# L0008468                     FIRST FLIGHT LIMITED PARTNERSHIP  ACTIVE
# M0008849                     CENTRE GROUP LIMITED PARTNERSHIP  ACTIVE
# L0006991    ATLEE STORAGE ASSOCIATES, A VIRGINIA LIMITED P...  INACTIVE
# L0007353                     MARKS FAMILY LIMITED PARTNERSHIP  INACTIVE
# L0005563    QUINCY STREET STATION ASSOCIATES LIMITED PARTN...  INACTIVE
# L0007833                   FMB ASSOCIATES LIMITED PARTNERSHIP  ACTIVE
# L0008351                  FRENCH BROTHERS LIMITED PARTNERSHIP  INACTIVE
# L0007684                SACRAMENTO CENTER LIMITED PARTNERSHIP  INACTIVE
# L0006637    GHA-WATERFRONT II DEVELOPMENT ASSOCIATES LIMIT...  INACTIVE
# L0008625                               RIVANNA PARTNERS, L.P.  INACTIVE
# L0008195              BRITTANY ASSOCIATES LIMITED PARTNERSHIP  INACTIVE
# L0009680     GREENBRIER TECHNOLOGY CENTER II ASSOCIATES, L.P.  INACTIVE
# L0008773       JEFFERSON DAVIS ASSOCIATES LIMITED PARTNERSHIP  INACTIVE
# L0010233                   AIRLINE BOULEVARD ASSOCIATES, L.P.  INACTIVE
# L0010258                            FOX REST ASSOCIATES, L.P.  INACTIVE
# M0010399         COLONIAL SELF STORAGE, A LIMITED PARTNERSHIP  INACTIVE
# L0010415                   PANNILL FAMILY LIMITED PARTNERSHIP  ACTIVE
# L0010506     EQUITY INVESTMENT ASSOCIATES LIMITED PARTNERSHIP  ACTIVE
# L0010464     ROBERT L. BORUM & ASSOCIATES LIMITED PARTNERSHIP  INACTIVE
# L0010522                            GATEHOUSE ASSOCIATES L.P.  ACTIVE
# L0010563      ALEXANDRIA SOUTH ASSOCIATES LIMITED PARTNERSHIP  INACTIVE
# L0009110                          GRAY LOBLOLLY COMPANY, L.P.  ACTIVE
# L0004483                MONROE ASSOCIATES LIMITED PARTNERSHIP  INACTIVE
#
#            IncorpDate IncorpState                               Street1  \
# EntityID
# L0002297     1/5/1987  VA                         1001 EAST MAIN STREET
# L0005506     1/6/1987  VA                                 P.O. Box 9035
# L0005704    1/14/1987  VA                               1529 Salem Road
# L0005886    1/15/1987  VA                          5721 Thurston Avenue
# L0004970    1/16/1987  VA                              115 SHOCKOE SLIP
# L0006215    1/20/1987  VA                             10670 Lee Highway
# M0006397    1/21/1987  DE                           10400 Fernwood Road
# L0005035    1/21/1987  VA                            4217 S PLAZA TRAIL
# L0001869    1/23/1987  VA                            c/o Drucker & Falk
# L0006793    1/28/1987  VA                              Route 1  Box 510
# M0007015    1/30/1987  MD                  2000 TOWER OAKS BLVD 8TH FLR
# M0007114    1/30/1987  MD                         7316 Wisconsin Avenue
# L0007932     2/2/1987  VA                         560 Lynnhaven Parkway
# L0007213     2/2/1987  VA                         7601 Lewinsville Road
# L0007171     2/2/1987  VA                         7601 Lewinsville Road
# M0005746     2/3/1987  MD                        1051 East Broad Street
# L0007551     2/5/1987  VA                  4656 BRAMBLETON AVENUE  S.W.
# M0004996     2/6/1987  MD                     c/o Henry A. Long Company
# M0001463     2/6/1987  MD                 c/o The Henry A. Long Company
# L0008500              4401 FORD AVENUE  #300       ALEXANDRIA
# L0008468                                           CHANTILLY
# M0008849            One Harry . Truman Drive       Landover
# L0006991                  7110 Forest Avenue       Richmond
# L0007353                                           Capron
# L0005563            7500 OLD GEORGETOWN ROAD       BETHESDA
# L0007833                                      Ft. Myers Beach
# L0008351        FRENCH BUILDING  LAWYERS ROW       WOODSTOCK
# L0007684                        P.O. BOX 215      SPRINGFIELD
# L0006637                          Suite 301        Fairfax
# L0008625                   700 HARRIS STREET  CHARLOTTESVILLE
# L0008195      1615 M STREET  N.W.  SUITE 850       WASHINGTON
# L0009680                                           CHESAPEAKE
# L0008773                                           Arlington
# L0010233                       P.O. Box 3767       Norfolk
# L0010258                   701 East Byrd St.       Richmond
# M0010399                          Suite 515        Richmond
# L0010415                                         MARTINSVILLE
# L0010506                                           Washington
# L0010464                                           Richmond
# L0010522    8280 Greensboro Drive  Suite 790       McLean
# L0010563                   5285 SHAWNEE ROAD       ALEXANDRIA
# L0009110           5004 MONUMENT AVE STE 200       RICHMOND
# L0004483                                           Arlington
#
#                            State         Zip
# EntityID
# L0002297              Virginia    23219-0000
# L0005506              Virginia    22906-0000
# L0005704              Virginia    23456-0000
# L0005886              Virginia    23455-0000
# L0004970              Virginia    23219-0000
# L0006215              Virginia    22030-0000
# M0006397              Maryland    20058-0000
# L0005035              Virginia    23462-0000
# L0001869              Virginia    23607-0000
# L0006793              Virginia    22229-3900
# M0007015              Maryland         20852
# M0007114              Maryland    20814-0000
# L0007932              Virginia    23452-0000
# L0007213              Virginia    22102-0000
# L0007171              Virginia    22102-0000
# M0005746              Virginia    22046-0000
# L0007551              Virginia    24018-0000
# M0004996              Virginia    22030-0000
# M0001463              Virginia    22030-0000
# L0001307              Virginia    22110-0000
# L0006470              Virginia    22906-0000
# M0005910              Maryland    20058-0000
# L0004434              Virginia    22202-0000
# M0006868          North Carolina  27408-3000
# L0008559              Virginia    23060-5813
# L0008450              Virginia    24141-0000
# L0008500              Virginia    22302-0000
# L0008468              Virginia    20151-0000
# M0008849              Maryland    20785-5339
# L0006991              Virginia    23226-3000
# L0007353              Virginia    23829-0000
# L0005563              Maryland    20814-0000
# L0007833              Florida     33931-0000
# L0008351              Virginia    22664-0000
# L0007684              Virginia    22150-0000
# L0006637              Virginia    22031-2031
# L0008625              Virginia    22901-0000
# L0008195    District Of Columbia  20036-0000
# L0009680              Virginia    23320-0000
# L0008773              Virginia    22202-0000
# L0010233              Virginia    23235-1400
# L0010258              Virginia    23219-0000
# M0010399              Virginia    23225-0000
# L0010415              Virginia    24112-0000
# L0010506    District Of Columbia  20036-5538
# L0010464              Virginia    23226-0000
# L0010522              Virginia    22102-0000
# L0010563              Virginia    22312-0000
# L0009110              Virginia    23230-0000
# L0004483              Virginia    22202-0000
